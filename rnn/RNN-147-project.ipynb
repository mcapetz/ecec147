# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/text-generation
# Out:
# /content/drive/My Drive/Colab Notebooks/text-generation

# %%
from google.colab import files
try:
  # so we don't download the data each time we run the cell
  read_file = open('glove.6B.50d.txt', "r")
except:
  # !wget http://nlp.stanford.edu/data/glove.6B.zip
  # !unzip glove.6B.zip
  # !ls -lat
  read_file = open('glove.6B.50d.txt', "r")

# %%
# !python train.py --name="model_6" --max-epochs=30
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !python train.py --name="model_3" --max-epochs=20
# Out:
# Streaming output truncated to the last 5000 lines.
# {'epoch': 6, 'batch': 266, 'loss': 6.391311168670654}
# {'epoch': 6, 'batch': 267, 'loss': 6.37013053894043}
# {'epoch': 6, 'batch': 268, 'loss': 6.152292728424072}
# {'epoch': 6, 'batch': 269, 'loss': 6.454458713531494}
# {'epoch': 6, 'batch': 270, 'loss': 6.550701141357422}
# {'epoch': 6, 'batch': 271, 'loss': 6.591275215148926}
# {'epoch': 6, 'batch': 272, 'loss': 7.045485973358154}
# {'epoch': 6, 'batch': 273, 'loss': 6.276156425476074}
# {'epoch': 6, 'batch': 274, 'loss': 6.404660224914551}
# {'epoch': 6, 'batch': 275, 'loss': 6.521655082702637}
# {'epoch': 6, 'batch': 276, 'loss': 6.458958148956299}
# {'epoch': 6, 'batch': 277, 'loss': 6.355322360992432}
# {'epoch': 6, 'batch': 278, 'loss': 6.870607376098633}
# {'epoch': 6, 'batch': 279, 'loss': 6.688870429992676}
# {'epoch': 6, 'batch': 280, 'loss': 6.182381629943848}
# {'epoch': 6, 'batch': 281, 'loss': 6.219212532043457}
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

epoch_loss_values = [6.878738290800465, 6.634282141623737, 6.5902382727149575, 6.551740734182673, 6.515878178575914, 6.492180648639048, 6.471869738324941, 6.45126871891159, 6.43680129154123, 6.433035675570261]

plt.plot(np.arange(len(epoch_loss_values)), epoch_loss_values)

# %%
# !python train.py --name="model_4"
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
import matplotlib.pyplot as plt
import numpy as np

epoch_loss_values = [6.822964900351585, 6.510468064470494, 6.504281503088931, 6.50074950558074, 6.49732221441066, 6.492170245089429, 6.476942412396695, 6.45462100176101, 6.441607268566781, 6.431168625963495, 6.418993168688835, 6.4044187145030245, 6.411357087023715, 6.427992685044066, 6.407299233243821, 6.4031806943264415, 6.403839134155436, 6.395030667173102, 6.38814154584357, 6.381340777620356]

plt.plot(np.arange(len(epoch_loss_values)), epoch_loss_values)

# %%
text= "In a world where machines had emotions"
# !python train.py --load=True --model_path="/content/drive/MyDrive/Colab Notebooks/text-generation/models/model_5" --text=text
# Out:
# ['<pad>' '<unk>' 'the' ',' '.' 'of' 'to' 'and' 'in' 'a']
# (400002, 100)
# 11264
# ['<pad>' '<unk>' 'the' ',' '.' 'of' 'to' 'and' 'in' 'a']
# (400002, 100)
# ['text', 'of', '1.', 'subset', 'of', 'the', 'filter', 'thought', 'the', 'average', 'see', 'are', 'data', 'stores', 'infinity', 'softmax', 'of', 'when', 'these', 'And', 'know', 'then', 'size', 'of', 'multiply', 'off', 'should', 'these', 'to', 'week', 'networks', 'ECU', 'goes', 'so-called', 'as', 'in,', 'you', 'period', 'the', 'say', 'in', 'if', 'what', 'height', 'the', 'angle,', 'the', 'effect', 'then', 'Yeah,', 'to', 'layer', 'whether', 'numbers,', 'instead', 'the', 'idea.', 'back', 'will', 'out', 'expect', 'a', 'trial', 'out,', 'the', 'minus', 'kind', 'about', 'today.', 'VA', 'signals', 'both', 'four', 'for', 'go', 'if', 'looks', 'into', 'this', 'class', 'And', 'H', 'uh,', "we'll", 'the', 'Then', 'the', 'You', 'to', 'Monday.', 'over', 'slides.', 'actually', 'can', 'Alright,', 'And', 'that', 'have', 'And', 'chip', 'by']

# %%
text="The universe is a vast and mysterious place, full of wonders and secrets"
# !python train.py --load=True --model_path="/content/drive/MyDrive/Colab Notebooks/text-generation/models/model_5" --text=text
# Out:
# ['<pad>' '<unk>' 'the' ',' '.' 'of' 'to' 'and' 'in' 'a']
# (400002, 100)
# 11264
# ['<pad>' '<unk>' 'the' ',' '.' 'of' 'to' 'and' 'in' 'a']
# (400002, 100)
# ...
